# %%
import sqlite3

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from datetime import date, timedelta

# %%
con = sqlite3.connect("campaign_finance.db")

# %%
cur = con.cursor()

# %%
cur.execute("DROP TABLE IF EXISTS contributions;")

# %%
cur.execute("DROP TABLE IF EXISTS contributors;")

# %%
cur.execute("DROP TABLE IF EXISTS candidates;")

# %%
con.commit()

# %%
cur.execute("""                            #actually creating each of the three table objects we will later insert synthetic data into
  CREATE TABLE candidates (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    party TEXT, #setting format/type for column data
    office TEXT,
    winner INTEGER  -- 1 = winner, 0 = not winner (SQLite stores booleans as integers)
  );
""")
# Out:
# Traceback (most recent call last):
#   File "c:\Users\karra\.vscode\extensions\ms-python.python-2026.4.0-win32-x64\python_files\python_server.py", line 139, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# sqlite3.OperationalError: near "#actually": syntax error

# %%
cur.execute("""                            #actually creating each of the three table objects we will later insert synthetic data into
  CREATE TABLE candidates (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    party TEXT, #setting format/type for column data
    office TEXT,
    winner INTEGER  -- 1 = winner, 0 = not winner (SQLite stores booleans as integers)
  );
""")
# Out:
# Traceback (most recent call last):
#   File "c:\Users\karra\.vscode\extensions\ms-python.python-2026.4.0-win32-x64\python_files\python_server.py", line 139, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# sqlite3.OperationalError: near "#actually": syntax error

# %%
cur.execute("""                            
  CREATE TABLE candidates (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    party TEXT, #setting format/type for column data
    office TEXT,
    winner INTEGER  -- 1 = winner, 0 = not winner (SQLite stores booleans as integers)
  );
""")
# Out:
# Traceback (most recent call last):
#   File "c:\Users\karra\.vscode\extensions\ms-python.python-2026.4.0-win32-x64\python_files\python_server.py", line 139, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# sqlite3.OperationalError: near "#setting": syntax error

# %%
cur.execute("""                            
  CREATE TABLE candidates (
    id INTEGER PRIMARY KEY,
    name TEXT NOT NULL,
    party TEXT, 
    office TEXT,
    winner INTEGER  -- 1 = winner, 0 = not winner (SQLite stores booleans as integers)
  );
""")

# %%
cur.execute("""
  CREATE TABLE contributors (
    id INTEGER PRIMARY KEY,
    name TEXT,
    occupation TEXT,
    employer TEXT,
    state TEXT
  );
""")

# %%
cur.execute("""
  CREATE TABLE contributions (
    id INTEGER PRIMARY KEY,
    contributor_id INTEGER,
    candidate_id INTEGER,
    amount REAL,
    date TEXT,
    FOREIGN KEY (contributor_id) REFERENCES contributors(id), #QUESTION: need explanation for this
    FOREIGN KEY (candidate_id) REFERENCES candidates(id)
  );
""")

con.commit()
# Out:
# Traceback (most recent call last):
#   File "c:\Users\karra\.vscode\extensions\ms-python.python-2026.4.0-win32-x64\python_files\python_server.py", line 139, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
# sqlite3.OperationalError: near "#QUESTION": syntax error

# %%
cur.execute("""
  CREATE TABLE contributions (
    id INTEGER PRIMARY KEY,
    contributor_id INTEGER,
    candidate_id INTEGER,
    amount REAL,
    date TEXT,
    FOREIGN KEY (contributor_id) REFERENCES contributors(id),
    FOREIGN KEY (candidate_id) REFERENCES candidates(id)
  );
""")

# %%
con.commit() #loads empty table into dataframe (shortcut "con")

# %%
np.random.seed(123)

# %%
candidate_ids = np.arange(1, 101)

# %%
candidate_names = np.array([f"Candidate {i}" for i in candidate_ids])

# %%
candidate_parties = np.random.choice(
    ["Democrat", "Republican", "Independent"],
    size=100,
    replace=True,
    p=[0.45, 0.45, 0.10]
)

# %%
candidate_offices = np.random.choice(
    ["Senate", "House", "Governor", "State Senate", "State House"],
    size=100,
    replace=True
)

# %%
candidate_winner = np.random.choice(
    [1, 0],
    size=100,
    replace=True,
    p=[0.5, 0.5]
)

# %%
candidates = pd.DataFrame({
    "id": candidate_ids,
    "name": candidate_names,
    "party": candidate_parties,
    "office": candidate_offices,
    "winner": candidate_winner
})

# %%
contributor_ids = np.arange(1, 100001)

# %%
contributor_names = np.array([f"Contributor {i}" for i in contributor_ids])

# %%
contributor_occupations = np.random.choice(
    ["Engineer", "Teacher", "Doctor", "Lawyer", "Business Owner"],
    size=100000,
    replace=True
)

# %%
contributor_employers = np.array([f"Company {i}" for i in np.random.randint(1, 5001, size=100000)])

# %%
state_abb = [
    "AL","AK","AZ","AR","CA","CO","CT","DE","FL","GA",
    "HI","ID","IL","IN","IA","KS","KY","LA","ME","MD",
    "MA","MI","MN","MS","MO","MT","NE","NV","NH","NJ",
    "NM","NY","NC","ND","OH","OK","OR","PA","RI","SC",
    "SD","TN","TX","UT","VT","VA","WA","WV","WI","WY"
]

# %%
contributor_states = np.random.choice(state_abb, size=100000, replace=True)

# %%
contributors = pd.DataFrame({
    "id": contributor_ids,
    "name": contributor_names,
    "occupation": contributor_occupations,
    "employer": contributor_employers,
    "state": contributor_states
})

# %%
contribution_ids = np.arange(1, 1000001)

# %%
contribution_contributor_ids = np.random.randint(1, 100001, size=1000000)

# %%
contribution_candidate_ids = np.random.randint(1, 101, size=1000000)

# %%
contribution_amounts = np.round(
    np.random.lognormal(mean=np.log(1000), sigma=1, size=1000000),
    2
)

# %%
start_date = date(2024, 1, 1)

# %%
end_date = date(2024, 12, 31)

# %%
n_days = (end_date - start_date).days + 1

# %%
random_day_offsets = np.random.randint(0, n_days, size=1000000)

# %%
contribution_dates = np.array([(start_date + timedelta(days=int(d))).isoformat() for d in random_day_offsets])

# %%
contributions = pd.DataFrame({
    "id": contribution_ids,
    "contributor_id": contribution_contributor_ids,
    "candidate_id": contribution_candidate_ids,
    "amount": contribution_amounts,
    "date": contribution_dates
})

# %%
candidates.to_sql("candidates", con, if_exists="append", index=False, chunksize=5000)
# Out:
# 100

# %%
contributors.to_sql("contributors", con, if_exists="append", index=False, chunksize=5000)
# Out:
# 100000

# %%
contributions.to_sql("contributions", con, if_exists="append", index=False, chunksize=5000)
# Out:
# 1000000

# %%
con.commit()

# %%
cur.execute("CREATE INDEX IF NOT EXISTS idx_contrib_contributor_id ON contributions (contributor_id);")

# %%
cur.execute("CREATE INDEX IF NOT EXISTS idx_contrib_candidate_id   ON contributions (candidate_id);")

# %%
cur.execute("CREATE INDEX IF NOT EXISTS idx_contrib_amount         ON contributions (amount);")

# %%
cur.execute("CREATE INDEX IF NOT EXISTS idx_contrib_date           ON contributions (date);")

# %%
con.commit()

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Sanity checks: table sizes")
# Out:
# Sanity checks: table sizes

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(pd.read_sql_query("SELECT COUNT(*) AS n_candidates FROM candidates;", con))
# Out:
#    n_candidates
# 0           100

# %%
print(pd.read_sql_query("SELECT COUNT(*) AS n_contributors FROM contributors;", con))
# Out:
#    n_contributors
# 0          100000

# %%
print(pd.read_sql_query("SELECT COUNT(*) AS n_contributions FROM contributions;", con))
# Out:
#    n_contributions
# 0          1000000

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Sanity checks: sample rows")
# Out:
# Sanity checks: sample rows

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(pd.read_sql_query("SELECT * FROM candidates LIMIT 5;", con))
# Out:
#    id         name       party       office  winner
# 0   1  Candidate 1  Republican       Senate       0
# 1   2  Candidate 2    Democrat        House       1
# 2   3  Candidate 3    Democrat       Senate       1
# 3   4  Candidate 4  Republican     Governor       0
# 4   5  Candidate 5  Republican  State House       1

# %%
print(pd.read_sql_query("""
  SELECT
    co.id,
    co.candidate_id,
    ca.name AS candidate_name,
    co.amount,
    co.date
  FROM contributions co                      ##from "contributions" table
  JOIN candidates ca                         ##join to "candidates" table
    ON co.candidate_id = ca.id               ##join by "candidate_ID" column
  LIMIT 5;
""", con))
# Out:
# Traceback (most recent call last):
#   File "C:\Users\karra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py", line 2702, in execute
#     cur.execute(sql, *args)
# sqlite3.OperationalError: unrecognized token: "#"
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "c:\Users\karra\.vscode\extensions\ms-python.python-2026.4.0-win32-x64\python_files\python_server.py", line 139, in exec_user_input
#     retval = callable_(user_input, user_globals)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 1, in <module>
#   File "C:\Users\karra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py", line 497, in read_sql_query
#     return pandas_sql.read_query(
#            ^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py", line 2766, in read_query
#     cursor = self.execute(sql, params)
#              ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\karra\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\pandas\io\sql.py", line 2714, in execute
#     raise ex from exc
# pandas.errors.DatabaseError: Execution failed on sql '
#   SELECT
#     co.id,
#     co.candidate_id,
#     ca.name AS candidate_name,
#     co.amount,
#     co.date
#   FROM contributions co                      ##from "contributions" table
#   JOIN candidates ca                         ##join to "candidates" table
#     ON co.candidate_id = ca.id               ##join by "candidate_ID" column
#   LIMIT 5;
# ': unrecognized token: "#"

# %%
print(pd.read_sql_query("""
  SELECT
    co.id,
    co.candidate_id,
    ca.name AS candidate_name,
    co.amount,
    co.date
  FROM contributions co                      
  JOIN candidates ca                         
    ON co.candidate_id = ca.id               
  LIMIT 5;
""", con))
# Out:
#    id  candidate_id candidate_name   amount        date
# 0   1            23   Candidate 23  6672.59  2024-09-13
# 1   2            92   Candidate 92  1589.57  2024-06-29
# 2   3            43   Candidate 43   862.13  2024-11-19
# 3   4            56   Candidate 56   721.32  2024-07-27
# 4   5            21   Candidate 21   432.60  2024-07-11

# %%
query_1 = """
  SELECT
    c.occupation,
    SUM(co.amount) AS total_amount, 
    COUNT(*) AS num_contributions   
  FROM contributors c
  JOIN contributions co
    ON c.id = co.contributor_id
  GROUP BY c.occupation
  ORDER BY total_amount DESC
  LIMIT 10;
"""

# %%
top_occupations = pd.read_sql_query(query_1, con)

# %%
print("\n------------------------------")
print("Top 10 occupations by total contribution amount")
print("------------------------------")
print(top_occupations)
# Out:
# ------------------------------
# Top 10 occupations by total contribution amount
# ------------------------------
#        occupation  total_amount  num_contributions
# 0          Doctor  3.343554e+08             202617
# 1          Lawyer  3.313582e+08             200684
# 2         Teacher  3.289318e+08             199347
# 3        Engineer  3.271291e+08             198419
# 4  Business Owner  3.265969e+08             198933

# %%
query_2 = """
  SELECT
    ca.party,
    SUM(co.amount) AS total_amount,
    SUM(co.amount) * 100.0 / (
      SELECT SUM(amount)
      FROM contributions
      WHERE amount > 1000
    ) AS percentage
  FROM contributions co
  JOIN candidates ca
    ON co.candidate_id = ca.id
  WHERE co.amount > 1000
  GROUP BY ca.party;
"""

# %%
party_pct = pd.read_sql_query(query_2, con)

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Percent of total contributions by party (amount > $1000)")
# Out:
# Percent of total contributions by party (amount > $1000)

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(party_pct)
# Out:
#          party  total_amount  percentage
# 0     Democrat  6.384598e+08   46.031278
# 1  Independent  6.843453e+07    4.933951
# 2   Republican  6.801186e+08   49.034772

# %%
query_3 = """
  SELECT
    ca.id AS candidate_id,
    ca.name,
    ca.party,
    COUNT(DISTINCT c.state) AS num_states,
    COUNT(co.id) AS contribution_count
  FROM candidates ca
  JOIN contributions co
    ON ca.id = co.candidate_id
  JOIN contributors c
    ON co.contributor_id = c.id
  GROUP BY ca.id, ca.name, ca.party
  ORDER BY num_states DESC, contribution_count DESC
  LIMIT 5;
"""

# %%
candidates_most_states = pd.read_sql_query(query_3, con)

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Candidates with contributions from the most distinct states")
# Out:
# Candidates with contributions from the most distinct states

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(candidates_most_states)
# Out:
#    candidate_id          name       party  num_states  contribution_count
# 0            28  Candidate 28    Democrat          50               10277
# 1            95  Candidate 95  Republican          50               10214
# 2            25  Candidate 25  Republican          50               10206
# 3            29  Candidate 29    Democrat          50               10188
# 4            62  Candidate 62  Republican          50               10179

# %%
query_4 = """
  SELECT
    c.name,
    GROUP_CONCAT(DISTINCT ca.party) AS parties,
    SUM(CASE WHEN ca.party = 'Democrat' THEN co.amount ELSE 0 END) AS dem_amount,
    SUM(CASE WHEN ca.party = 'Republican' THEN co.amount ELSE 0 END) AS rep_amount
  FROM contributors c
  JOIN contributions co
    ON c.id = co.contributor_id
  JOIN candidates ca
    ON co.candidate_id = ca.id
  GROUP BY c.id
  HAVING COUNT(DISTINCT ca.party) > 1
  LIMIT 20;
"""

# %%
cross_party = pd.read_sql_query(query_4, con)

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Cross-party contributors (sample)")
# Out:
# Cross-party contributors (sample)

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(cross_party)
# Out:
#               name                          parties  dem_amount  rep_amount
# 0    Contributor 1  Democrat,Republican,Independent     6776.50     7761.66
# 1    Contributor 2              Republican,Democrat    11268.56    25670.87
# 2    Contributor 3              Republican,Democrat    10522.40    15110.54
# 3    Contributor 4  Democrat,Republican,Independent     5396.82    19879.15
# 4    Contributor 5              Democrat,Republican     3488.26     9688.83
# 5    Contributor 7              Republican,Democrat     2187.08    19820.92
# 6    Contributor 8              Democrat,Republican    49074.22     4139.93
# 7    Contributor 9  Republican,Democrat,Independent     5303.15    25053.74
# 8   Contributor 10              Democrat,Republican    11409.52     6952.21
# 9   Contributor 11              Democrat,Republican     7469.02     7170.98
# 10  Contributor 12              Democrat,Republican    10299.53     8230.24
# 11  Contributor 13  Republican,Independent,Democrat    12439.42     3949.86
# 12  Contributor 14              Democrat,Republican     6733.34     8860.57
# 13  Contributor 15              Democrat,Republican     8791.50    15668.97
# 14  Contributor 16              Republican,Democrat     3822.60    14167.95
# 15  Contributor 17              Democrat,Republican     1783.23     7475.42
# 16  Contributor 18              Republican,Democrat     4819.35    10528.36
# 17  Contributor 19  Republican,Democrat,Independent     8309.46     9814.46
# 18  Contributor 20  Republican,Democrat,Independent     1673.70    20422.15
# 19  Contributor 21              Republican,Democrat     5948.92    26581.98

# %%
query_5 = """
  WITH ranked_contributions AS (
    SELECT
      ca.id,
      ca.name,
      co.date,
      co.amount,
      SUM(co.amount) OVER (
        PARTITION BY ca.id
        ORDER BY co.date
      ) AS cumulative_amount
    FROM candidates ca
    JOIN contributions co
      ON ca.id = co.candidate_id
  ),
  windowed_avg AS (
    SELECT
      id,
      name,
      date,
      amount,
      AVG(amount) OVER (
        PARTITION BY id
        ORDER BY date
        ROWS BETWEEN 29 PRECEDING AND CURRENT ROW
      ) AS moving_avg
    FROM ranked_contributions
  )
  SELECT
    id,
    name,
    date,
    amount,
    moving_avg
  FROM windowed_avg
  WHERE id IN (
    SELECT id
    FROM ranked_contributions
    GROUP BY id
    ORDER BY MAX(cumulative_amount) DESC
    LIMIT 3
  )
  ORDER BY id, date
  LIMIT 100;
"""

moving_avg = pd.read_sql_query(query_5, con)

# %%
moving_avg = pd.read_sql_query(query_5, con)

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Moving average contributions (top 3 candidates, sample rows)")
# Out:
# Moving average contributions (top 3 candidates, sample rows)

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(moving_avg)
# Out:
#     id          name        date   amount   moving_avg
# 0   28  Candidate 28  2024-01-01  1352.80  1352.800000
# 1   28  Candidate 28  2024-01-01  1295.12  1323.960000
# 2   28  Candidate 28  2024-01-01  1609.53  1419.150000
# 3   28  Candidate 28  2024-01-01   605.19  1215.660000
# 4   28  Candidate 28  2024-01-01   211.12  1014.752000
# ..  ..           ...         ...      ...          ...
# 95  28  Candidate 28  2024-01-04  3317.37  1631.899333
# 96  28  Candidate 28  2024-01-04  1287.52  1647.256667
# 97  28  Candidate 28  2024-01-04   338.43  1640.841667
# 98  28  Candidate 28  2024-01-04   393.48  1533.640000
# 99  28  Candidate 28  2024-01-04  2776.72  1601.147000
#
# [100 rows x 5 columns]

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
query_6 = """
  SELECT
    ca.party,
    SUM(co.amount) AS total_amount
  FROM contributions co
  JOIN candidates ca
    ON co.candidate_id = ca.id
  GROUP BY ca.party;
"""

# %%
party_totals = pd.read_sql_query(query_6, con)

# %%
print("\n------------------------------")
# Out:
# ------------------------------

# %%
print("Total contributions by party")
# Out:
# Total contributions by party

# %%
print("------------------------------")
# Out:
# ------------------------------

# %%
print(party_totals)
# Out:
#          party  total_amount
# 0     Democrat  7.584284e+08
# 1  Independent  8.159493e+07
# 2   Republican  8.083480e+08

# %%
plt.figure()
# Out:
# Figure(640x480)

# %%
plt.bar(party_totals["party"], party_totals["total_amount"])
# Out:
# <BarContainer object of 3 artists>

# %%
plt.title("Total Contributions by Party")
# Out:
# Text(0.5, 1.0, 'Total Contributions by Party')

# %%
plt.xlabel("Party")
# Out:
# Text(0.5, 0, 'Party')

# %%
plt.ylabel("Total Amount ($)")
# Out:
# Text(0, 0.5, 'Total Amount ($)')

# %%
plt.tight_layout()

# %%
plt.savefig("contributions_by_party.png", dpi=150)

# %%
plt.show()
